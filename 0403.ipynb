# %% [markdown]
# <a href="https://colab.research.google.com/github/ydadwhal/DSA-SMVDU/blob/main/0403.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv('a.csv')

# %%
df1.head(10)
# Out:
#    Rank            Country Name  Male Height in Cm  Female Height in Cm  \
# 0     1             Netherlands             183.78               170.36
# 1     2              Montenegro             183.30               169.96
# 2     3                 Estonia             182.79               168.66
# 3     4  Bosnia and Herzegovina             182.47               167.47
# 4     5                 Iceland             182.10               168.91
# 5     6                 Denmark             181.89               169.47
# 6     7          Czech Republic             181.19               167.96
# 7     8                  Latvia             181.17               168.81
# 8     9                Slovakia             181.02               167.12
# 9    10                Slovenia             180.98               167.20
#
#    Male Height in Ft  Female Height in Ft
# 0               6.03                 5.59
# 1               6.01                 5.58
# 2               6.00                 5.53
# ...

# %%
df1.columns
# Out:
# Index(['Rank', 'Country Name', 'Male Height in Cm', 'Female Height in Cm',
#        'Male Height in Ft', 'Female Height in Ft'],
#       dtype='object')

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=199, step=1)

# %%
df2=df1[['Country Name','Male Height in Cm']]
# Out:
# 0      183.78
# 1      183.30
# 2      182.79
# 3      182.47
# 4      182.10
#         ...
# 194    164.30
# 195    163.10
# 196    163.07
# 197    162.78
# 198    160.13
# Name: Male Height in Cm, Length: 199, dtype: float64

# %%
df2
# Out:
#                Country Name  Male Height in Cm
# 0               Netherlands             183.78
# 1                Montenegro             183.30
# 2                   Estonia             182.79
# 3    Bosnia and Herzegovina             182.47
# 4                   Iceland             182.10
# ..                      ...                ...
# 194              Mozambique             164.30
# 195        Papua New Guinea             163.10
# 196         Solomon Islands             163.07
# 197                    Laos             162.78
# 198             Timor-Leste             160.13
#
# [199 rows x 2 columns]

# %%
df2=df1.copy()

# %%
df2[['Rank', 'Country Name', 'Male Height in Cm']]
# Out:
#      Rank            Country Name  Male Height in Cm
# 0       1             Netherlands             183.78
# 1       2              Montenegro             183.30
# 2       3                 Estonia             182.79
# 3       4  Bosnia and Herzegovina             182.47
# 4       5                 Iceland             182.10
# ..    ...                     ...                ...
# 194   195              Mozambique             164.30
# 195   196        Papua New Guinea             163.10
# 196   197         Solomon Islands             163.07
# 197   198                    Laos             162.78
# 198   199             Timor-Leste             160.13
#
# [199 rows x 3 columns]

# %%
df2.describe()
# Out:
#              Rank  Male Height in Cm  Female Height in Cm  Male Height in Ft  \
# count  199.000000         199.000000           199.000000         199.000000
# mean   100.000000         173.089045           160.942915           5.678794
# std     57.590508           4.949832             4.076377           0.162510
# min      1.000000         160.130000           150.910000           5.250000
# 25%     50.500000         169.490000           158.240000           5.560000
# 50%    100.000000         173.530000           160.620000           5.690000
# 75%    149.500000         176.510000           163.870000           5.790000
# max    199.000000         183.780000           170.360000           6.030000
#
#        Female Height in Ft
# count           199.000000
# mean              5.280402
# std               0.133870
# min               4.950000
# 25%               5.190000
# 50%               5.270000
# 75%               5.375000
# max               5.590000

# %%
df2[]

df2[df2['Male Height in Cm']>180]
# Out:
#     Rank    Country Name  Male Height in Cm  Female Height in Cm  \
# 0      1     Netherlands             183.78               170.36
# 1      2      Montenegro             183.30               169.96
# 2      3         Estonia             182.79               168.66
# 4      5         Iceland             182.10               168.91
# 5      6         Denmark             181.89               169.47
# 6      7  Czech Republic             181.19                  NaN
# 8      9        Slovakia             181.02               167.12
# 9     10        Slovenia             180.98               167.20
# 10    11         Ukraine             180.98               166.62
# 11    12         Croatia             180.76               166.80
# 12    13          Serbia             180.74               168.29
# 13    14       Lithuania             180.72               167.63
# 14    15          Poland             180.69                  NaN
# ...

# %%
df2.columns
# Out:
# Index(['Rank', 'Country Name', 'Male Height in Cm', 'Female Height in Cm',
#        'Male Height in Ft', 'Female Height in Ft'],
#       dtype='object')

# %%
means=(df2[['Male Height in Cm', 'Female Height in Cm',
                'Male Height in Ft', 'Female Height in Ft']].mean())

# %%
type(means)
# Out:
# list

# %%
df3=df2[['Male Height in Cm', 'Female Height in Cm']].loc[0:5]
df3
# Out:
#    Male Height in Cm  Female Height in Cm
# 0             183.78               170.36
# 1             183.30               169.96
# 2             182.79               168.66
# 3                NaN                  NaN
# 4             182.10               168.91
# 5             181.89               169.47

# %%
df3.fillna(value=means,inplace=True)

# %%
df3
# Out:
#    Male Height in Cm  Female Height in Cm
# 0         183.780000           170.360000
# 1         183.300000           169.960000
# 2         182.790000           168.660000
# 3         172.911237           160.836051
# 4         182.100000           168.910000
# 5         181.890000           169.470000

# %%
area={'Maharashtra':39872934.33,'HP':293849234.223,'TN':234324923.34}

# %%
population={'Maharashtra':1231,'MP':234,'HP':345}

# %%
df5=pd.DataFrame(data=[area,population])

# %%
df5
# Out:
#    Maharashtra            HP            TN     MP
# 0  39872934.33  2.938492e+08  2.343249e+08    NaN
# 1      1231.00  3.450000e+02           NaN  234.0
